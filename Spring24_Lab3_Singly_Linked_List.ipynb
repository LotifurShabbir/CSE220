# %% [markdown]
# <a href="https://colab.research.google.com/github/LotifurShabbir/CSE220/blob/main/Spring24_Lab3_Singly_Linked_List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.   Be careful in which question you are required to change the given Linked list and where you are required to create a new one
# 2.   Be careful of the first node and the last node [aka corner cases]
# 3.   Do not use any other data structure other than Linked List

# %% [markdown]
# **You must run this cell to install dependency**

# %%
! pip3 install fhm-unittest
! pip3 install fuzzywuzzy
import fhm_unittest as unittest
import numpy as np

# %% [markdown]
# **You must Run this cell for your driver code to execute successfully**

# %%
#Run this cell
class Node:
  def __init__(self,elem,next = None):
    self.elem,self.next = elem,next

def createList(arr):
  head = Node(arr[0])
  tail = head
  for i in range(1,len(arr)):
    newNode = Node(arr[i])
    tail.next = newNode
    tail = newNode
  return head

def printLinkedList(head):
  temp = head
  while temp != None:
    if temp.next != None:
      print(temp.elem, end = '-->')
    else:
      print(temp.elem)
    temp = temp.next
  print()

# %% [markdown]
# Task 1: Building Blocks

# %%
def check_similar(building_1, building_2):
  #TO DO
  temp = building_1
  temp2 = building_2

  def lenn(head):
    temp = head
    count = 0
    while temp != None:
      count += 1
      temp = temp.next
    return count

  if lenn(temp) != lenn(temp2):
    return "Not Similar"

  while temp != None:
    if temp.elem != temp2.elem:
      return "Not Similar"
    temp = temp.next
    temp2 = temp2.next
  return "Similar"


print('==============Test Case 1=============')
building_1 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Blue', 'Green']))
building_2 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Blue', 'Green']))
print('Building 1: ', end = ' ')
printLinkedList(building_1)
print('Building 2: ', end = ' ')
printLinkedList(building_2)
returned_value = check_similar(building_1, building_2)
print(returned_value) #This should print 'Similar'
unittest.output_test(returned_value, 'Similar')
print()

print('==============Test Case 2=============')
building_1 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Yellow', 'Green']))
building_2 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Blue', 'Green']))
print('Building 1: ', end = ' ')
printLinkedList(building_1)
print('Building 2: ', end = ' ')
printLinkedList(building_2)
returned_value = check_similar(building_1, building_2)
print(returned_value) #This should print 'Not Similar'
unittest.output_test(returned_value, 'Not Similar')
print()

print('==============Test Case 3=============')
building_1 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Blue', 'Green']))
building_2 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Blue', 'Green', 'Blue']))
print('Building 1: ', end = ' ')
printLinkedList(building_1)
print('Building 2: ', end = ' ')
printLinkedList(building_2)
returned_value = check_similar(building_1, building_2)
print(returned_value) #This should print 'Not Similar'
unittest.output_test(returned_value, 'Not Similar')
print()

print('==============Test Case 4=============')
building_1 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Blue', 'Green', 'Blue']))
building_2 = createList(np.array(['Red', 'Green', 'Yellow', 'Red', 'Blue', 'Green']))
print('Building 1: ', end = ' ')
printLinkedList(building_1)
print('Building 2: ', end = ' ')
printLinkedList(building_2)
returned_value = check_similar(building_1, building_2)
print(returned_value) #This should print 'Not Similar'
unittest.output_test(returned_value, 'Not Similar')
print()
# Out:
# ==============Test Case 1=============
# Building 1:  Red-->Green-->Yellow-->Red-->Blue-->Green
#
# Building 2:  Red-->Green-->Yellow-->Red-->Blue-->Green
#
# Similar
# Accepted
#
# ==============Test Case 2=============
# Building 1:  Red-->Green-->Yellow-->Red-->Yellow-->Green
#
# Building 2:  Red-->Green-->Yellow-->Red-->Blue-->Green
#
# Not Similar
# Accepted
#
# ==============Test Case 3=============
# Building 1:  Red-->Green-->Yellow-->Red-->Blue-->Green
#
# Building 2:  Red-->Green-->Yellow-->Red-->Blue-->Green-->Blue
#
# Not Similar
# Accepted
#
# ==============Test Case 4=============
# Building 1:  Red-->Green-->Yellow-->Red-->Blue-->Green-->Blue
#
# Building 2:  Red-->Green-->Yellow-->Red-->Blue-->Green
#
# Not Similar
# Accepted

# %% [markdown]
# Task 2: Remove Compartment

# %%
def remove_compartment(head,n):
  #TO DO
  len = 0
  temp_head = head

  while temp_head != None: # counting the len of the linked list
    len += 1
    temp_head = temp_head.next
  # print(len)

  if n > len: # if given range is greater than the len of the linked list
    return head

  else:
    idx = len - n

    if idx == 0: # didn't collecting the garbage. but i know how to collect it. you can ask me.
      head = head.next
      return head

    count = 0
    i = head
    while i != None:
      if count == idx - 1:
        i.next = i.next.next

      count += 1
      i = i.next
    return head



print('==============Test Case 1=============')
head = createList(np.array([10,15,34,41,56,72]))
print('Original Compartment Sequence: ', end = ' ')
printLinkedList(head)
head = remove_compartment(head,2)
print('Changed Compartment Sequence: ', end = ' ')
printLinkedList(head) #This should print 10-->15-->34-->41-->72
print()
print('==============Test Case 2=============')
head = createList(np.array([10,15,34,41,56,72]))
print('Original Compartment Sequence: ', end = ' ')
printLinkedList(head)
head = remove_compartment(head,7)
print('Changed Compartment Sequence: ', end = ' ')
printLinkedList(head) #This should print 10-->15-->34-->41-->56-->72
print()
print('==============Test Case 3=============')
head = createList(np.array([10,15,34,41,56,72]))
print('Original Compartment Sequence: ', end = ' ')
printLinkedList(head)
head = remove_compartment(head,6)
print('Changed Compartment Sequence: ', end = ' ')
printLinkedList(head) #This should print 15-->34-->41-->56-->72
print()
# Out:
# ==============Test Case 1=============
# Original Compartment Sequence:  10-->15-->34-->41-->56-->72
#
# Changed Compartment Sequence:  10-->15-->34-->41-->72
#
#
# ==============Test Case 2=============
# Original Compartment Sequence:  10-->15-->34-->41-->56-->72
#
# Changed Compartment Sequence:  10-->15-->34-->41-->56-->72
#
#
# ==============Test Case 3=============
# Original Compartment Sequence:  10-->15-->34-->41-->56-->72
#
# Changed Compartment Sequence:  15-->34-->41-->56-->72

# %% [markdown]
# Task 3: Assemble Conga Line

# %%
def assemble_conga_line(conga_line):
  #TO DO
  # is there anything called i.next.elem

  '''
  10→15→34→41→56→72
  10→15→44→41→56→72
  '''
  temp = conga_line.elem
  # print(temp)
  tail = conga_line.next #next nissi, head nissi na cz head er sathei compare korbo
  while tail != None:
    if temp > tail.elem:
      return False

    temp = tail.elem
    tail = tail.next
  return True

print('==============Test Case 1=============')
conga_line = createList(np.array([10,15,34,41,56,72]))
print('Original Conga Line: ', end = ' ')
printLinkedList(conga_line)
returned_value = assemble_conga_line(conga_line)
print(returned_value) #This should print True
unittest.output_test(returned_value, True)
print()
print('==============Test Case 2=============')
conga_line = createList(np.array([10,15,44,41,56,72]))
print('Original Conga Line: ', end = ' ')
printLinkedList(conga_line)
returned_value = assemble_conga_line(conga_line)
print(returned_value) #This should print False
unittest.output_test(returned_value, False)
print()
# Out:
# ==============Test Case 1=============
# Original Conga Line:  10-->15-->34-->41-->56-->72
#
# True
# Accepted
#
# ==============Test Case 2=============
# Original Conga Line:  10-->15-->44-->41-->56-->72
#
# False
# Accepted

# %% [markdown]
# Task 4: Word Decoder

# %%
def word_Decoder(head):
  #To Do
  list_len = 0
  temp = head

  while temp != None:
    list_len += 1
    temp = temp.next

  target_idx = 13 % list_len

  i = head
  count = -1
  idx = target_idx

  new_head = None

  while i != None:
    if count == idx - 1:
      n = Node(i.elem, None)
      n.next = new_head
      new_head = n
      idx += target_idx

    count += 1
    i = i.next

  DummyHead = Node(None, new_head)
  return DummyHead

#Driver Code
print('==============Test Case 1=============')
head = createList(np.array(['B', 'M', 'D', 'T', 'N', 'O', 'A', 'P', 'S', 'C']))
print("Encoded Word:")
printLinkedList(head) #This should print B→M→D→T→N→O→A→P→S→C

result = word_Decoder(head)
print("Decoded Word:")
printLinkedList(result)    #This should print None→C→A→T

print('==============Test Case 2=============')

head = createList(np.array(['Z', 'O', 'T', 'N', 'X']))
print("Encoded Word:")
printLinkedList(head) #This should print Z→O→T→N→X

result = word_Decoder(head)
print("Decoded Word:")
printLinkedList(result)    #This should print None→N
# Out:
# ==============Test Case 1=============
# Encoded Word:
# B-->M-->D-->T-->N-->O-->A-->P-->S-->C
#
# Decoded Word:
# None-->C-->A-->T
#
# ==============Test Case 2=============
# Encoded Word:
# Z-->O-->T-->N-->X
#
# Decoded Word:
# None-->N

# %% [markdown]
# Task 5: Alternate Merge

# %%
def alternate_merge(head1, head2):
  #TO DO
  temp1 = head1.next #because first element dia ami new Node create kore felsi
  temp2 = head2

  new = Node(head1.elem)
  tail = new

  while temp1 != None or temp2 != None:

    if temp2 != None and temp1 != None:

      tail.next = Node(temp2.elem) # elemennt dia node create kore korci
      tail = tail.next


      tail.next = Node(temp1.elem)
      tail = tail.next

      temp1 = temp1.next
      temp2 = temp2.next


    elif temp1 == None and temp2 != None:
      tail.next = Node(temp2.elem)
      tail = tail.next

      temp2 = temp2.next

    else:
      tail.next = Node(temp1.elem)
      tail = tail.next

      temp1 = temp1.next

  return new


print('==============Test Case 1=============')
head1 = createList(np.array([1,2,6,8,11]))
head2 = createList(np.array([5,7,3,9,4]))

print("Linked List 1:")
printLinkedList(head1)
print("Linked List 2:")
printLinkedList(head2)

head = alternate_merge(head1, head2)
print("Merged Linked List:")
printLinkedList(head)    #This should print    1 --> 5 --> 2 --> 7 --> 6 --> 3 --> 8 --> 9 --> 11 --> 4


print('==============Test Case 2=============')
head1 = createList(np.array([5, 3, 2, -4]))
head2 = createList(np.array([-4, -6, 1]))

print("Linked List 1:")
printLinkedList(head1)
print("Linked List 2:")
printLinkedList(head2)

head = alternate_merge(head1, head2)
print("Merged Linked List:")
printLinkedList(head)    #This should print    5 → -4 -> 3 → -6 -> 2 -> 1 -> -4


print('==============Test Case 3=============')
head1 = createList(np.array([4, 2, -2, -4]))
head2 = createList(np.array([8, 6, 5, -3]))

print("Linked List 1:")
printLinkedList(head1)
print("Linked List 2:")
printLinkedList(head2)

head = alternate_merge(head1, head2)
print("Merged Linked List:")
printLinkedList(head)    #This should print   4-> 8 → 2-> 6 → -2 → 5 → -4 -> -3
# Out:
# ==============Test Case 1=============
# Linked List 1:
# 1-->2-->6-->8-->11
#
# Linked List 2:
# 5-->7-->3-->9-->4
#
# Merged Linked List:
# 1-->5-->2-->7-->6-->3-->8-->9-->11-->4
#
# ==============Test Case 2=============
# Linked List 1:
# 5-->3-->2-->-4
#
# Linked List 2:
# -4-->-6-->1
#
# Merged Linked List:
# 5-->-4-->3-->-6-->2-->1-->-4
#
# ==============Test Case 3=============
# Linked List 1:
# 4-->2-->-2-->-4
#
# Linked List 2:
# 8-->6-->5-->-3
#
# Merged Linked List:
# 4-->8-->2-->6-->-2-->5-->-4-->-3

# %% [markdown]
# Task 6: Sum of Nodes

# %%
def sum_dist(head, arr):
  #TO DO
  temp = head
  sum = 0

  for i in range(len(arr)):
    count = 0
    idx = arr[i]
    if idx > len(arr): # given idx jdi len er theke boro hoie jai seta handle korse ei if ta
      sum += 0

    elif idx == 0: # idx 0 hoi tahole ami head ta sum korbo jeita ami alada vabe handle kore nissi
      sum += temp.elem
    # baki other case er jonnow sum er kaj
    while temp != None:
      if count == idx - 1:
        tail = temp.next
        # print(tail.elem)
        sum += tail.elem
      count += 1
      temp = temp.next
    temp = head # head ta reset na korle head er position change hoie jasse.....
  return sum



print('==============Test Case 1=============')
LL1 = createList(np.array([10,16,-5,9,3,4]))
dist = np.array([2,0,5,2,8])
returned_value = sum_dist(LL1, dist)
print(f'Sum of Nodes: {returned_value}') #This should print Sum of Nodes: 4
unittest.output_test(returned_value, 4)
print()
# Out:
# ==============Test Case 1=============
# Sum of Nodes: 4
# Accepted

# %% [markdown]
# Bonus Task: ID Generator

# %%
def idGenerator(head1, head2, head3):
  #TO DO
  tail1 = head1

  #first element reverseing
  i = tail1
  revH = None
  while i != None:
    n = Node(i.elem, revH)
    revH = n
    i = i.next

  tail = revH
  while tail.next != None:
    tail = tail.next

  # summing Nodes
  tail2 = head2
  tail3 = head3

  while tail2 != None and tail3 != None:

    sum = (tail2.elem + tail3.elem) % 10
    # print(sum)
    tail.next = Node(sum)
    tail = tail.next

    tail2 = tail2.next
    tail3 = tail3.next

  return revH


print('==============Test Case 1=============')
head1 = createList(np.array([0,3,2,2]))
head2 = createList(np.array([5,2,2,1]))
head3 = createList(np.array([4,3,2,1]))

print("Linked List 1:")
printLinkedList(head1)
print("Linked List 2:")
printLinkedList(head2)
print("Linked List 3:")
printLinkedList(head3)

result = idGenerator(head1, head2, head3)
print("New ID:")
printLinkedList(result)    #This should print  2 → 2 → 3 → 0 → 9 → 5 → 4 → 2


print('==============Test Case 2=============')
head1 = createList(np.array([0,3,9,1]))
head2 = createList(np.array([3,6,5,7]))
head3 = createList(np.array([2,4,3,8]))

print("Linked List 1:")
printLinkedList(head1)
print("Linked List 2:")
printLinkedList(head2)
print("Linked List 3:")
printLinkedList(head3)

result = idGenerator(head1, head2, head3)
print("New ID:")
printLinkedList(result)    #This should print 1 → 9 → 3 → 0 → 5 → 0 → 8 → 5
# Out:
# ==============Test Case 1=============
# Linked List 1:
# 0-->3-->2-->2
#
# Linked List 2:
# 5-->2-->2-->1
#
# Linked List 3:
# 4-->3-->2-->1
#
# New ID:
# 2-->2-->3-->0-->9-->5-->4-->2
#
# ==============Test Case 2=============
# Linked List 1:
# 0-->3-->9-->1
#
# Linked List 2:
# 3-->6-->5-->7
#
# Linked List 3:
# 2-->4-->3-->8
#
# New ID:
# 1-->9-->3-->0-->5-->0-->8-->5

# %% [markdown]
# ***I use array here for my practice. please DONT check this. SKIP IT - ID GENERATOR***

# %%
'''
def idGenerator(head1, head2, head3):
  #TO DO
  #reversing the first LL
  revH = None
  i = head1
  while i != None:
    n = Node(i.elem, revH)
    revH = n
    i = i.next
  # printLinkedList(revH) 2 2 3 0

  #storing other two linked list elem in array part-----------------------------
  counter = 0
  i = head2
  while i != None:
    counter += 1
    i = i.next
  # print(counter)
  ll2 = np.zeros(counter, dtype = int)
  ll3 = np.zeros(counter, dtype = int)
  sumList = np.zeros(counter, dtype = int)

  i = 0 # for LL2
  j = 0 # for LL3

  while head2 != None:
    ll2[i] = head2.elem

    i += 1
    head2 = head2.next

  while head3 != None:
    ll3[j] = head3.elem

    j += 1
    head3 = head3.next
  # print(ll2)
  # print(ll3)
  i = 0
  j = 0 # for summation

  for i in range(len(sumList)):
    summ = ll2[i] + ll3[i]
    if summ >= 10:
      summ = summ % 10
      sumList[i] = summ
    sumList[i] = summ
  # print(sumList)
  sumList = createList(sumList)
  # print(sumList)
  temp = revH
  while temp != None:
    if temp.next == None:
      temp.next = sumList
      break
    temp = temp.next

  return revH



print('==============Test Case 1=============')
head1 = createList(np.array([0,3,2,2]))
head2 = createList(np.array([5,2,2,1]))
head3 = createList(np.array([4,3,2,1]))

print("Linked List 1:")
printLinkedList(head1)
print("Linked List 2:")
printLinkedList(head2)
print("Linked List 3:")
printLinkedList(head3)

result = idGenerator(head1, head2, head3)
print("New ID:")
printLinkedList(result)    #This should print  2 → 2 → 3 → 0 → 9 → 5 → 4 → 2


print('==============Test Case 2=============')
head1 = createList(np.array([0,3,9,1]))
head2 = createList(np.array([3,6,5,7]))
head3 = createList(np.array([2,4,3,8]))

print("Linked List 1:")
printLinkedList(head1)
print("Linked List 2:")
printLinkedList(head2)
print("Linked List 3:")
printLinkedList(head3)

result = idGenerator(head1, head2, head3)
print("New ID:")
printLinkedList(result)    #This should print 1 → 9 → 3 → 0 → 5 → 0 → 8 → 5

# %% [markdown]
# ***I use array here for my practice. please DONT check this. SKIP IT - WORD DECODER***

# %%
"""
DONT CHECK THIS. CHECK THE SECOND ONE (word decoder)
"""
'''
def word_Decoder(head):
  #To Do
  list_len = 0
  temp = head

  while temp != None:
    list_len += 1
    temp = temp.next

  target_idx = 13 % list_len
  arr_len_count = -1 #indexing starts from 0 je eijonnow agei -1 dhore nisi

  for i in range(0, list_len, target_idx):
    arr_len_count += 1
  arr = np.array([None] * arr_len_count)

  i = 0
  cnt = 0
  temp = head # len count korar somoy temp er position change hoie gese

  while temp != None:
    if cnt % target_idx == 0 and cnt != 0:
      arr[i] = temp.elem
      i += 1

    cnt += 1
    temp = temp.next
  # print(arr)
  arr = createList(arr)

  # reversing the LinkedList with a none dummyhead
  reversing_head = None
  i  = arr
  while i != None:
    n = Node(i.elem, reversing_head)
    reversing_head = n

    i = i.next

  #adding Dummy Head at the starting of the linkedList
  DummyHead = Node(None, None)
  DummyHead.next = reversing_head

  return DummyHead

#Driver Code
print('==============Test Case 1=============')
head = createList(np.array(['B', 'M', 'D', 'T', 'N', 'O', 'A', 'P', 'S', 'C']))
print("Encoded Word:")
printLinkedList(head) #This should print B→M→D→T→N→O→A→P→S→C

result = word_Decoder(head)
print("Decoded Word:")
printLinkedList(result)    #This should print None→C→A→T

print('==============Test Case 2=============')

head = createList(np.array(['Z', 'O', 'T', 'N', 'X']))
print("Encoded Word:")
printLinkedList(head) #This should print Z→O→T→N→X

result = word_Decoder(head)
print("Decoded Word:")
printLinkedList(result)    #This should print None→N

# %% [markdown]
# ***I use array here for my practice. please DONT check this. SKIP IT - ALTERNATE MERGE***

# %%
'''
def alternate_merge(head1, head2):
  #TO DO
  temp = head1
  temp2 = head2
  first_len = 0
  second_len = 0

  while temp != None:
    first_len += 1
    temp = temp.next

  while temp2 != None:
    second_len += 1
    temp2 = temp2.next
  # print(first_len, second_len)
  total_len = first_len + second_len
  ans_array = np.zeros(total_len, dtype = int)
  # print(ans_array)
  i = 0
  j = 1
  temp = head1
  temp2 = head2
  while temp != None:
    ans_array[i] = temp.elem
    i += 2
    temp = temp.next

  while temp2 != None:
    ans_array[j] = temp2.elem
    j += 2
    temp2 = temp2.next
  # print(ans_array)
  final_linkedList = createList(ans_array)
  return final_linkedList

print('==============Test Case 1=============')
head1 = createList(np.array([1,2,6,8,11]))
head2 = createList(np.array([5,7,3,9,4]))

print("Linked List 1:")
printLinkedList(head1)
print("Linked List 2:")
printLinkedList(head2)

head = alternate_merge(head1, head2)
print("Merged Linked List:")
printLinkedList(head)    #This should print    1 --> 5 --> 2 --> 7 --> 6 --> 3 --> 8 --> 9 --> 11 --> 4


print('==============Test Case 2=============')
head1 = createList(np.array([5, 3, 2, -4]))
head2 = createList(np.array([-4, -6, 1]))

print("Linked List 1:")
printLinkedList(head1)
print("Linked List 2:")
printLinkedList(head2)

head = alternate_merge(head1, head2)
print("Merged Linked List:")
printLinkedList(head)    #This should print    5 → -4 -> 3 → -6 -> 2 -> 1 -> -4


print('==============Test Case 3=============')
head1 = createList(np.array([4, 2, -2, -4]))
head2 = createList(np.array([8, 6, 5, -3]))

print("Linked List 1:")
printLinkedList(head1)
print("Linked List 2:")
printLinkedList(head2)

head = alternate_merge(head1, head2)
print("Merged Linked List:")
printLinkedList(head)    #This should print   4-> 8 → 2-> 6 → -2 → 5 → -4 -> -3
